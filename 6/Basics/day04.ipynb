# %% [markdown]
# # SETS

# %% [markdown]
# ## 1

# %%
numbers = [1, 2, 2, 3, 4, 4, 5, 5, 5]

numbers = set(numbers)
numbers
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## 2

# %%
python_students = {"Alice", "Bob", "Charlie", "David"}
ml_students = {"Bob", "David", "Eve", "Frank"}


print(f"Both: {python_students & ml_students}")
print(f"Atleast one: {python_students | ml_students}")
print(f"Python only: {python_students - ml_students}")
# Out:
# Both: {'Bob', 'David'}
# Atleast one: {'Charlie', 'Eve', 'Bob', 'David', 'Alice', 'Frank'}
# Python only: {'Alice', 'Charlie'}

# %% [markdown]
# ## 3

# %%
a = {10, 20, 30, 40, 50}
b = {30, 40, 50, 60, 70}

print(f"Intersection: {a & b}")
print(f"Union: {a | b}")
print(f"Difference: {a - b}")
# Out:
# Intersection: {40, 50, 30}
# Union: {70, 40, 10, 50, 20, 60, 30}
# Difference: {10, 20}

# %% [markdown]
# ## 5

# %%
numbers = {i: i**2 for i in range(1,11)}
numbers
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# ## 6

# %%
scores = {
    "Alice": 85,
    "Bob": 72,
    "Charlie": 91,
    "David": 64,
    "Eve": 88
}

students = { key: value  for key, value in scores.items() if value>=80}
students
# Out:
# {'Alice': 85, 'Charlie': 91, 'Eve': 88}

# %% [markdown]
# # CLASSES

# %% [markdown]
# ## 1

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

new_car = Car('Ford', 'f40', '2020')
print(new_car.brand)
# Out:
# Ford

# %% [markdown]
# ## 2

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year
    def describe(self):
        return print(f"{self.brand} {self.model} ({self.year})")

new_car = Car('Ford', 'f40', '2020')
print(new_car.describe())
# Out:
# <bound method Car.describe of <__main__.Car object at 0x00000282E8CD6900>>

# %% [markdown]
# ## 3

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance
        

    def deposit(self, amount):
        
        self.balance += amount
        return (f"Balance: {self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return (f"Balance: {self.balance}")
        else:
            return "Insufficient balance"


a1 = BankAccount("Xmen", 1000)
a1.deposit(10)
a1.withdraw(1110)
# Out:
# 'Insufficient balance'

# %% [markdown]
# ## 4

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name 
        self.marks = marks

    def average(self):
        avg =  sum(self.marks) / len(self.marks)
        return (f"Average marks of {self.name} is {avg}")

    def highest(self):
        return f"Highest marks {max(self.marks)}"
    def lowest(self):
        return f"Lowest marks {min(self.marks)}"


animesh = Student("Animesh Kadel", [8.5, 9.5, 10, 7, 6])
print(animesh.average())
print(animesh.highest())
print(animesh.lowest())
# Out:
# Average marks of Animesh Kadel is 8.2
# Highest marks 10
# Lowest marks 6
